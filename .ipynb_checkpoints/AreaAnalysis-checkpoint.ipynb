# %%
import geopandas as gpd
import pandas as pd
import networkx as nx
import osmnx as ox
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Creating GeoDataframes</h2>

# %% [markdown]
# <h3>Datasets</h3>

# %%
#Seattle City Polygon
seaCity = gpd.read_file("./data/Seattle_Area_Polygon_-142470933516081067.geojson")
seaCity = seaCity.to_crs('EPSG:32610')

# %%
#Amsterdam City Polygon
amCity = ox.geocode_to_gdf('Amsterdam, North Holland, Netherlands')
amCity = amCity.to_crs('EPSG:32632')

# %%
#Seattle Bike Facilities
bike = gpd.read_file("./data/SDOT_Bike_Facilities_existing.geojson")
multi = gpd.read_file("./data/SDOT_Bike_Facilities_multiuse.geojson")
planned = gpd.read_file("./data/SDOT_Bike_Facilities_planned.geojson")
sBike = bike.to_crs('EPSG:32610')
sMulti = multi.to_crs('EPSG:32610')
sPlanned = planned.to_crs('EPSG:32610')

# %%
#merging datasets together
current_sBike = pd.concat([sBike, sMulti])
all_sBike = pd.concat([sBike, sMulti, sPlanned])

# %%
#Amsterdam Bike Facilities
url = "https://maps.amsterdam.nl/open_geodata/geojson_latlng.php?KAARTLAAG=FIETSNETTEN&THEMA=fietsnetten"
abike = gpd.read_file(url)
amBike = abike.to_crs('EPSG:32632')

# %% [markdown]
# <h3>Plots</h3>

# %%
seaCity.plot()
# Out:
# <Axes: >

# %%
current_sBike.plot()
# Out:
# <Axes: >

# %%
all_sBike.plot()
# Out:
# <Axes: >

# %%
amCity.plot()
# Out:
# <Axes: >

# %%
amBike.plot()
# Out:
# <Axes: >

# %% [markdown]
# <h2>Area Comparisions</h2>

# %%
seaArea = seaCity.area / 1000000
seaArea[0]
# Out:
# 238.03031395933098

# %%
amArea = amCity.area/1000000
amArea[0]
# Out:
# 219.74511133494627

# %% [markdown]
# <h3>Seattle Existing Bike Facilites</h3>

# %%
sBuffer = current_sBike.buffer(400)
sBufferGDF = gpd.GeoDataFrame(geometry=gpd.GeoSeries(sBuffer))
sDissolve = sBufferGDF.dissolve()
sClip = sDissolve.clip(seaCity)

# %%
sBikeArea = sClip.area / 1000000
sPercent = (sBikeArea / seaArea) * 100
print(f'One can access {sPercent[0]:.1f}% of Seattle by bike')
# Out:
# One can access 80.9% of Seattle by bike

# %%
#plot when polygon is outline and buffer is solid color and have bike lanes on top

# %% [markdown]
# <h3>Seattle Planned Bike Facilites</h3>

# %%
sBuffer_P = all_sBike.buffer(400)
sBufferGDF_P = gpd.GeoDataFrame(geometry=gpd.GeoSeries(sBuffer_P))
sDissolve_P = sBufferGDF_P.dissolve()
sClip_P = sDissolve_P.clip(seaCity)

# %%
sBikeArea_P = sClip_P.area / 1000000
sPercent_P = (sBikeArea_P / seaArea) * 100
print(f'One can access {sPercent_P[0]:.1f}% of Seattle by bike when the planned bike facilites are complete')
# Out:
# One can access 95.3% of Seattle by bike when the planned bike facilites are complete

# %% [markdown]
# <h3>Amsterdam Bike Facilites</h3>

# %%
amBike

# %%
aBuffer = amBike.buffer(400)
aBufferGDF = gpd.GeoDataFrame(geometry=gpd.GeoSeries(aBuffer))
aDissolve = aBufferGDF.dissolve()
aClip = aDissolve.clip(amCity)

# %%
aClip.plot()
# Out:
# /var/folders/6h/mjkfjbdx5j33s6js5qfxw5f40000gn/T/ipykernel_71907/951968236.py:1: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   aClip.plot()
# <Axes: >

# %%
aDissolve.crs
# Out:
# <Projected CRS: EPSG:32632>
# Name: WGS 84 / UTM zone 32N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°E and 12°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Austria. Cameroon. Denmark. Equatorial Guinea. France. Gabon. Germany. Italy. Libya. Liechtenstein. Monaco. Netherlands. Niger. Nigeria. Norway. Sao Tome and Principe. Svalbard. Sweden. Switzerland. Tunisia. Vatican City State.
# - bounds: (6.0, 0.0, 12.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 32N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
amCity.crs
# Out:
# <Projected CRS: EPSG:32632>
# Name: WGS 84 / UTM zone 32N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°E and 12°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Austria. Cameroon. Denmark. Equatorial Guinea. France. Gabon. Germany. Italy. Libya. Liechtenstein. Monaco. Netherlands. Niger. Nigeria. Norway. Sao Tome and Principe. Svalbard. Sweden. Switzerland. Tunisia. Vatican City State.
# - bounds: (6.0, 0.0, 12.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 32N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
aBikeArea = aClip.area / 1000000
aPercent = (aBikeArea / amArea) * 100
print(f'One can access {aPercent[0]:.1f}% of Seattle by bike')
# Out:
# One can access nan% of Seattle by bike

# %%
#might need to go back to old amsterdam polygon. The open street maps seems to be in differnt location

# %%
seattleG = ox.graph_from_place('Seattle, Washington, USA', network_type='bike')

# %%
# Plot map
fig, ax = ox.plot_graph(seattleG, bgcolor='white', node_color='black', edge_color='grey', node_size=5)

# %%
sCoords = [47.605465173774206, -122.3192423656039]
sNode = ox.distance.nearest_nodes(seattleG, X=sCoords[1], Y=sCoords[0], return_dist=False)

# %%
nodes = ox.graph_to_gdfs(seattleG, nodes=True, edges=False)
edges = ox.graph_to_gdfs(seattleG, nodes=False, edges=True)

# %%
travel_speed = 16
meters_per_minute = travel_speed * 1000 / 60  # km per hour to m per minute

for u, v, data in seattleG.edges.data():
    data['time'] = data['length'] / meters_per_minute

# %%
subgraph = nx.ego_graph(seattleG, sNode, radius=30, distance="time")
fig, ax = ox.plot_graph(subgraph, bgcolor='white', node_color='black', edge_color='grey', node_size=10)

# %%
trip_times = [5, 10, 15, 20, 25, 30]  # in minutes
iso_colors = ox.plot.get_colors(n=len(trip_times), cmap="plasma", start=0, return_hex=True)
# Out:
# /var/folders/6h/mjkfjbdx5j33s6js5qfxw5f40000gn/T/ipykernel_78626/3036243802.py:2: FutureWarning: The `return_hex` parameter has been deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   iso_colors = ox.plot.get_colors(n=len(trip_times), cmap="plasma", start=0, return_hex=True)

# %%
# color the nodes according to isochrone then plot the street network
node_colors = {}
for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
    subgraph1 = nx.ego_graph(seattleG, sNode, radius=trip_time, distance="time")
    for node in subgraph1.nodes():
        node_colors[node] = color

nc = [node_colors[node] if node in node_colors else "none" for node in seattleG.nodes()]
ns = [10 if node in node_colors else 0 for node in seattleG.nodes()]

# %%
fig, ax = ox.plot_graph(seattleG, node_color=nc, node_size=ns, node_alpha=0.8,
    edge_linewidth=0.2, edge_color="grey", bgcolor='white')

# %%
def make_iso_polys(G, edge_buff=25, node_buff=50, infill=False):
    isochrone_polys = []
    for trip_time in sorted(trip_times, reverse=True):
        subgraph = nx.ego_graph(G, sNode, radius=trip_time, distance='time')

        node_points = [Point((data['x'], data['y'])) for node, data in subgraph.nodes(data=True)]
        nodes_gdf = gpd.GeoDataFrame({'id': subgraph.nodes()}, geometry=node_points)
        nodes_gdf = nodes_gdf.set_index('id')

        edge_lines = []
        for n_fr, n_to in subgraph.edges():
            f = nodes_gdf.loc[n_fr].geometry
            t = nodes_gdf.loc[n_to].geometry
            edge_lookup = G.get_edge_data(n_fr, n_to)[0].get('geometry',  LineString([f,t]))
            edge_lines.append(edge_lookup)

        n = nodes_gdf.buffer(node_buff).geometry
        e = gpd.GeoSeries(edge_lines).buffer(edge_buff).geometry
        all_gs = list(n) + list(e)
        new_iso = gpd.GeoSeries(all_gs).unary_union
        
        # try to fill in surrounded areas so shapes will appear solid and blocks without white space inside them
        if infill:
            new_iso = Polygon(new_iso.exterior)
        isochrone_polys.append(new_iso)
    return isochrone_polys

# %%
isochrone_polys = make_iso_polys(seattleG, edge_buff=25, node_buff=0, infill=True)

# %%
fig, ax = ox.plot_graph(seattleG, show=False, close=False, edge_linewidth=0.2, 
                        edge_color="grey", bgcolor='white', edge_alpha=0.2, node_size=0)
for polygon, fc in zip(isochrone_polys, iso_colors):
    patch = PolygonPatch(polygon, fc=fc, ec='none', alpha=0.6, zorder=-1)
    ax.add_patch(patch)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 4
#       1 fig, ax = ox.plot_graph(seattleG, show=False, close=False, edge_linewidth=0.2,
#       2                         edge_color="grey", bgcolor='white', edge_alpha=0.2, node_size=0)
#       3 for polygon, fc in zip(isochrone_polys, iso_colors):
# ----> 4     patch = PolygonPatch(polygon, fc=fc, ec='none', alpha=0.6, zorder=-1)
#       5     ax.add_patch(patch)
#       6 plt.show()
#
# File ~/.gds/lib/python3.12/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# ...

# %% [markdown]
# <h3>Amsterdam</h3>
